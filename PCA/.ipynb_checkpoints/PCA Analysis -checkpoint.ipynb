# %%
import pandas as pd
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
from sklearn.preprocessing import StandardScaler
import numpy as np
from IPython.display import IFrame as show
import plotly
import plotly.plotly as py
import plotly.graph_objs as go
plotly.tools.set_credentials_file(username='xpeigang', api_key='lwQSZWto6kkYyDeNh8SM')
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
master_df = pd.read_csv("master_final_merged_df_protein_gdp.csv")

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ### Analysis 1: PCA on different food sources

# %%
col_list = master_df.columns.tolist()
protein_col_list = col_list[4:19]

# Cereals is the total of others. No need to include it here 
protein_col_list.remove("Cereals")
protein_col_list_country = ["Country"]+protein_col_list

protein_group_df = master_df[protein_col_list_country]

# If Protein food group is empty. it is droped. 
df1 = protein_group_df[protein_group_df.isna().any(axis=1)]
# print ("Dropped Countries:{}".format(df1["Country"]))
protein_group_df.dropna(inplace = True)

protein_group_scaled = StandardScaler().fit_transform(protein_group_df[protein_col_list])
protein_group_df
# Out:
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                 Country   Milk  Bovine meat  \
# 0                           Afghanistan   6.02         2.01
# 1                               Albania  29.67         9.18
# 2                               Algeria  13.78         2.18
# 3                                Angola   1.02         3.27
# 4                   Antigua and Barbuda  12.22         5.39
# 5                             Argentina  14.70        27.16
# 6                               Armenia  19.04         7.72
# 7                             Australia  19.16        14.05
# 8                               Austria  21.55         6.90
# 9                            Azerbaijan  14.07         5.09
# 10                              Bahamas   9.09         9.52
# 11                           Bangladesh   2.01         0.54
# 12                             Barbados  10.08         6.63
# 13                              Belarus  14.12         7.69
# 14                              Belgium  23.38         5.60
# 15                               Belize   7.32         2.15
# 16                                Benin   0.78         1.25
# 17                              Bermuda   8.95        17.49
# 18     Bolivia (Plurinational State of)   4.17         7.16
# 19               Bosnia and Herzegovina  15.75         3.72
# 20                             Botswana   9.84         3.21
# 21                               Brazil  13.26        14.66
# 22                    Brunei Darussalam   6.19         4.17
# 23                             Bulgaria  14.28         1.55
# 24                         Burkina Faso   2.51         2.69
# 25                           Cabo Verde  10.55         0.94
# 26                             Cambodia   0.26         2.01
# 27                             Cameroon   1.41         1.67
# 28                               Canada  13.22        11.17
# 29             Central African Republic   1.40         6.89
# ..                                  ...    ...          ...
# 144                               Spain  14.52         4.94
# 145                           Sri Lanka   3.57         0.55
# 146                               Sudan  20.35        12.72
# 147                            Suriname   5.01         3.83
# 148                            Eswatini   4.70         5.97
# 149                              Sweden  26.95         9.34
# 150                         Switzerland  24.47         7.36
# 151                          Tajikistan   5.18         1.64
# 152                            Thailand   2.46         1.04
# 153                     North Macedonia  13.80         3.13
# 154                         Timor-Leste   0.86         0.60
# 155                                Togo   0.61         0.64
# 156                 Trinidad and Tobago   9.57         2.40
# 157                             Tunisia   9.86         2.21
# 158                              Turkey  17.04         5.07
# 159                        Turkmenistan  12.71        10.71
# 160                              Uganda   3.19         2.08
# 161                             Ukraine  13.80         3.47
# 162                United Arab Emirates  10.85         2.19
# 163                      United Kingdom  19.19         6.61
# 164         United Republic of Tanzania   3.43         2.37
# 165            United States of America  21.86        12.43
# 166                             Uruguay  20.76         9.99
# 167                          Uzbekistan  12.01        11.02
# 168                             Vanuatu   2.48         3.67
# 146  0.00    0.00    6.40          23.41
# 147  0.00    0.04    1.33           1.06
# 148  0.03    0.00    2.17           2.46
# 149  2.22    0.30    1.12           2.36
# 150  0.23    0.21    1.13           1.85
# 151  0.00    1.01    1.45           1.51
# 152  0.00    0.00    1.65           0.54
# 153  0.08    0.00    3.01           2.41
# 154  0.00    0.00    5.17           1.55
# 155  0.00    0.00    7.81           6.52
# 156  0.03    0.02    5.70           1.96
# 157  0.00    1.11    5.26           1.23
# 158  0.76    0.00    7.18           2.25
# 159  0.00    0.49    0.00           1.36
# 160  0.00    0.01   14.47           3.74
# 161  1.98    0.52    0.91           6.08
# 162  0.00    0.00   15.44           0.41
# 163  0.07    0.14    1.84           4.15
# 164  0.00    0.00   11.58           3.96
# 165  0.07    0.14    2.34           2.47
# 166  0.00    0.09    1.81           1.98
# 167  0.00    0.46    0.02           2.30
# 168  0.00    0.31    0.00           9.68
# 169  0.00    0.00    3.91           1.79
# 170  0.00    0.00    1.78           0.47
# 171  0.00    0.00    3.54           0.37
# 172  0.00    0.00    1.12           2.25
# 173  0.00    0.04    2.39           0.55
#
# [174 rows x 15 columns]

# %% [markdown]
# PCA

# %%
principalComponents = pca.fit_transform(protein_group_scaled)

pc_protein_1,pc_protein_2 = zip(*principalComponents)
protein_group_df["principal component 1"] = pc_protein_1
protein_group_df["principal component 2"] = pc_protein_2


X = protein_group_df[["principal component 1","principal component 2"]].values
protein_group_df.head()
# Out:
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                Country   Milk  Bovine meat  Sheep and goat meat  Pigmeat  \
# 0          Afghanistan   6.02         2.01                 2.02     0.00
# 1              Albania  29.67         9.18                 5.35     2.76
# 2              Algeria  13.78         2.18                 2.70     0.00
# 3               Angola   1.02         3.27                 0.44     2.34
# 4  Antigua and Barbuda  12.22         5.39                 0.60     3.26
#
#    Poultry  Eggs   Fish  Maize  Rice  Wheat   Rye  Barley  Pulses  \
# 0     0.79  0.32   0.02   0.57  2.89  37.12  0.00    0.72    1.56
# 1     4.91  3.24   1.50   0.36  1.22  33.71  0.13    0.03    3.06
# 2     2.30  2.09   1.23   3.09  0.50  43.03  0.00    2.61    4.55
# 3     5.55  0.51   4.14   8.80  1.55   8.46  0.00    0.00    5.23
# 4    18.59  1.30  13.11   0.39  2.15  13.39  0.00    0.00    1.66
#
#    Starchy roots  principal component 1  principal component 2
# 0           0.22              -0.518736              -1.454621
# 1           1.86               2.440719              -2.200208
# 2           2.67               0.596646              -2.699386
# 3           7.13              -1.686584              -0.548387
# 4           0.86               0.845285               1.230920

# %% [markdown]
# #### Continent Level

# %% [markdown]
# ###### Countries to Continent

# %%
# Code adapated from https://stackoverflow.com/questions/55910004/get-continent-name-from-country-using-pycountry

from pycountry_convert import country_alpha2_to_continent_code, country_name_to_country_alpha2,country_name_to_country_alpha3,country_alpha3_to_country_alpha2

continents_dict = {
    'NA': 'North America',
    'SA': 'South America', 
    'AS': 'Asia',
    'OC': 'Australia',
    'AF': 'Africa',
    'EU': 'Eurpoe'
}
countries = protein_group_df['Country'].tolist()

def convert_continents(countries):
    """
    This function tries to get the continent based on Country name.
    Since some countries names are differnt in the library we are using here,
    need to manually change those.
    
    This function also tries to rechieve an alpha 3 Country Code based on the name. 
    """
    continents = []
    country_codes = []
    for country in countries:
        try:
            country_code = country_name_to_country_alpha3(country)
            continent = continents_dict[country_alpha2_to_continent_code(country_name_to_country_alpha2(country))]
            continents.append(continent)
            country_codes.append(country_code)
        except KeyError:
            print(country)
            continents.append(country)
            country_codes.append(country)
    return continents,country_codes


continents,country_codes = convert_continents(countries)
# Out:
# Bolivia (Plurinational State of)
# China, Hong Kong SAR
# China, Macao SAR
# China, mainland
# China, Taiwan Province of
# Congo (note no data in Food suppley tables for DRC)
# CÃƒÂ´te d'Ivoire
# Iran (Islamic Republic of)
# Republic of Korea
# Eswatini
# North Macedonia
# Timor-Leste
# Venezuela (Bolivarian Republic of)

# %%
# Make a new column called Continent using the continents information we just get. 
protein_group_df["Continent"] = continents

# A manually constructed country to contienent and country to country code list for those which have variation in names. 
manual_continent_dict = {"Bolivia (Plurinational State of)":"South America"
                         ,"China, Hong Kong SAR":"Asia"
                         ,"China, mainland":"Asia"
                         ,"China, Macao SAR":"Asia"
                         ,"China, Taiwan Province of":"Asia"
                         ,"Congo (note no data in Food suppley tables for DRC)":"Africa"
                         ,"CÃƒÂ´te d'Ivoire":"Africa"
                        ,"Iran (Islamic Republic of)":"Asia"
                        ,"Republic of Korea":"Asia"
                        ,"Eswatini":"Africa"
                        ,"North Macedonia":"Europe"
                        ,"Timor-Leste":"Asia"
                        ,"Venezuela (Bolivarian Republic of)":"South America"}

manual_country_code_dict = {"Bolivia (Plurinational State of)":"BOL"
                         ,"China, Hong Kong SAR":"HKG"
                         ,"China, mainland":"CHN"
                         ,"China, Macao SAR":"MAC"
                         ,"China, Taiwan Province of":"TWN"
                         ,"Congo (note no data in Food suppley tables for DRC)":"COG"
                         ,"CÃƒÂ´te d'Ivoire":"CIV"
                        ,"Iran (Islamic Republic of)":"IRN"
                        ,"Republic of Korea":"KOR"
                        ,"Eswatini":"SWZ"
                        ,"North Macedonia":"MKD"
                        ,"Republic of North Macedonia":"MKD"
                        ,"Timor-Leste":"TLS"
                        ,"Venezuela (Bolivarian Republic of)":"VEN"}

# Replace missing ones with correct continents. 
protein_group_df[protein_group_df["Country"].isna()]
# principalDf.to_csv("test.csv")
protein_group_df["Continent"] = protein_group_df["Continent"].replace(manual_continent_dict)
# Out:
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:37: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Code adapted from https://github.com/mGalarnyk/Python_Tutorials/blob/master/Sklearn/PCA/PCA_Data_Visualization_Iris_Dataset_Blog.ipynb
import matplotlib.pyplot as plt

def pca_plot(colors,df,cluster_name):
    """
    This function makes a plot using matplotlib, which uses Principal Component 1 as x and 2 as y.
    Colors represent clusters. 
    In this case, cluster can be Continent, Region, and Income group.  
    """
    fig = plt.figure(figsize = (8,8))
    ax = fig.add_subplot(1,1,1) 
    ax.set_xlabel('Principal Component 1', fontsize = 10)
    ax.set_ylabel('Principal Component 2', fontsize = 10)
    ax.set_title('2 component PCA {}'.format(cluster_name), fontsize = 20)

    
    cluster_list = df[cluster_name].unique()
    print(cluster_list)
    for cluster,color in zip(cluster_list,colors):
        indicesToKeep = df[cluster_name] == cluster
        ax.scatter(df.loc[indicesToKeep, 'principal component 1']
               , df.loc[indicesToKeep, 'principal component 2']
               , c = color
               , s = 50)
    ax.legend(cluster_list)
    ax.grid()

# %%
colors = ['r', 'g', 'b','c','m','y']
pca_plot(colors,protein_group_df,"Continent")
# Out:
# ['Asia' 'Eurpoe' 'Africa' 'North America' 'South America' 'Australia'
#  'Europe']

# %% [markdown]
# ###### K means on Top of PCA (Unable to fix the legend here. Shape represents continent, and colors represent cluster)

# %%
#K means Clustering 
# Code adapted from https://github.com/mGalarnyk/Python_Tutorials/blob/master/Sklearn/PCA/PCA_Data_Visualization_Iris_Dataset_Blog.ipynb
from sklearn.cluster import KMeans

def perform_kmeans(X, n_clust):
    """
    This function handles K means clustering. 
    """
    model = KMeans(n_clust)
    model.fit(X)
    cluster_labels = model.predict(X)
    cent = model.cluster_centers_
    return (cluster_labels, cent)

def pca_kmeans_plot(colors, mark_shapes,df,cluster_name,centers):
    """
    This function makes a plot using matplotlib, which uses Principal Component 1 as x and 2 as y.
    Shapes represent clusters. 
    In this case, cluster can be Continent, Region, and Income group.  
    Colors represent the clusters kmeans assigns the point to. 
    """
    fig_k = plt.figure(figsize = (8,8))
    ax = fig_k.add_subplot(1,1,1) 
    ax.set_xlabel('Principal Component 1', fontsize = 10)
    ax.set_ylabel('Principal Component 2', fontsize = 10)
    ax.set_title('2 component PCA Kmeans Clustering {}'.format(cluster_name), fontsize = 20)

    cluster_list = df[cluster_name].unique()

    for cluster, ms in zip(cluster_list,mark_shapes):
        for kmeans_cluster,color in zip([i for i in range(len(colors))],colors):
            indicesToKeep = (df[cluster_name] == cluster) & (df["{}_Cluster".format(cluster_name)] == kmeans_cluster)
            ax.scatter(df.loc[indicesToKeep, 'principal component 1']
                   , df.loc[indicesToKeep, 'principal component 2']
                   , c = color
                   , marker = ms
                   , s = 50)

    ax.legend(mark_shapes,cluster_list)
    ax.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)
    ax.grid()

# %%
# Plot Contienent level 
X = protein_group_df[["principal component 1","principal component 2"]].values
continent_cluster_labels, continent_centers = perform_kmeans(X, 6)
protein_group_df["Continent_Cluster"] = continent_cluster_labels
mark_shapes = ['s','d','p','h','o','*']
colors = ['r', 'g', 'b','c','m','y']
pca_kmeans_plot(colors,mark_shapes,protein_group_df,"Continent",continent_centers)
# Out:
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support 's' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support 'd' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support 'p' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support 'h' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support 'o' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support '*' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists

# %%
def plot_plotly(df,cluster_name,centers,cluster_num,filename_prefix,additional):
    """
    This function draws plots using plotly. 
    It draws different traces with different shape and color based on the cluster and kmeans cluster it belongs to.abs
    In this case, cluster can be Continent, Region, and Income group. 
    
    Shape represents it's original cluster, and color represents the cluster K means assigns it to. 
    """
    data = []
    rainbow_colorscale =  [
    'rgb(150,0,90)','rgb(0,0,200)',
     'rgb(10,152,255)',
    'rgb(44,255,150)', 'rgb(151,255,0)',
    'rgb(255,234,0)','rgb(255,111,0)',
    'rgb(255,0,0)'
    ]
    if additional:
        kmeans_cluster_name = additional
    else:
        kmeans_cluster_name = "{}_Cluster".format(cluster_name)
        
    
    cluster_list = df[cluster_name].unique()
    for ms,cluster in enumerate(cluster_list):
        for kmeans_cluster in range(cluster_num):
            indicesToKeep = (df[cluster_name] == cluster) & (df[kmeans_cluster_name] == kmeans_cluster)
            trace0 = go.Scatter(
                x = df.loc[indicesToKeep, 'principal component 1'],
                y = df.loc[indicesToKeep, 'principal component 2'],
                name = str(cluster) + str(kmeans_cluster),
                mode = 'markers',
                marker = dict(
                    size = 9, 
                    color = rainbow_colorscale[kmeans_cluster],
                    line = dict(width = 1),
                    symbol = ms,
                ),
                text = df.loc[indicesToKeep,"Country"],
            )
            data.append(trace0);
    method = ""
    if centers != "no center":
        trace1 = go.Scatter(
            x = centers[:, 0],
            y = centers[:, 1],
            name = "Center",
            mode = 'markers',
            marker = dict(
                size = 20, 
                color = 'rgba(220, 220, 220, .4)', 
                line = dict(width = 1),
                ),
                )
        data.append(trace1)
        method = "K means"
    else:
        method = "Spectral"

    layout= go.Layout(
        title= '2 component PCA calculated with {} Data {} Clustering {} with {} clusters'.format(filename_prefix, method,cluster_name,cluster_num),
        hovermode= 'closest',
        xaxis= dict(
            title= 'principal component 1',
            ticklen= 5,
            zeroline= False,
            gridwidth= 2,
        ),
        yaxis=dict(
            title= 'principal component 2',
            ticklen= 5,
            gridwidth= 2,
        ),
        showlegend= True
        )

    fig = dict(data=data, layout=layout)
    iplot(fig)
    py.iplot(fig, filename="{} {} Level Plot ".format(filename_prefix, cluster_name))

# %%
# Calling plotly function 
plot_plotly(protein_group_df,"Continent",continent_centers,6,"Protein Foods",'')
# Out:
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:44: FutureWarning:
#
# elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <div>
#
#
#             <div id="308e0158-e6b8-4749-9882-9217d018b69f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("308e0158-e6b8-4749-9882-9217d018b69f")) {
#                     Plotly.newPlot(
#                         '308e0158-e6b8-4749-9882-9217d018b69f',
#                         [{"marker": {"color": "rgb(150,0,90)", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "Asia0", "text": ["Democratic People's Republic of Korea", "India", "Nepal", "Timor-Leste"], "type": "scatter", "uid": "33281db5-66b9-43b1-a5c1-3abe843322c8", "x": [-2.551465145811014, -2.0959486456016725, -2.523104044473208, -2.7522535994625725], "y": [0.3474933616505065, 0.0243895474006073, -0.2713983772673335, 0.26068317493344]}, {"marker": {"color": "rgb(0,0,200)", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "Asia1", "text": ["Israel"], "type": "scatter", "uid": "5276abc7-9dee-421d-9a62-16ca19598a12", "x": [2.4091805886740962], "y": [-0.17670548022002946]}, {"marker": {"color": "rgb(10,152,255)", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "Asia2", "text": ["Armenia", "Azerbaijan", "Kazakhstan", "Kyrgyzstan", "Mongolia", "Turkey", "Turkmenistan", "Uzbekistan"], "type": "scatter", "uid": "3ff784ed-5e8c-4ad0-85d2-01a83e27701b", "x": [1.6741653766049829, 1.271725220438081, 2.001162515135617, 0.6016375020744401, 0.8852401981092998, 0.8515084271113968, 1.8159607067811956, 1.014084698739387], "y": [-1.0182527145102853, -2.2691708350668742, -1.6938835111056045, -2.1325228581750464, -4.0631784394527415, -1.8205513924393848, -3.1893678498892077, -1.8515767267611185]}, {"marker": {"color": "rgb(44,255,150)", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "Asia3", "text": ["Bangladesh", "Cambodia", "Indonesia", "Lao People's Democratic Republic", "Myanmar", "Philippines", "Sri Lanka", "Thailand", "Viet Nam"], "type": "scatter", "uid": "650f0b2b-0e9f-43cb-b458-771c33bc5665", "x": [-2.962684688345844, -2.8248081720444738, -2.2890441738492946, -2.8200792765449934, -2.0710873548630757, -1.5796232332802, -2.318022669366338, -1.1864198859602553, -1.50291321372396], "y": [2.1555619555372973, 2.99292814800493, 2.1569054803508503, 2.683118812916563, 2.9179985639464845, 2.3922639719170817, 1.6227672996973552, 2.373955824236931, 3.1915220599529985]}, {"marker": {"color": "rgb(151,255,0)", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "Asia4", "text": ["Brunei Darussalam", "China, Hong Kong SAR", "China, Macao SAR", "China, mainland", "China, Taiwan Province of", "Japan", "Malaysia", "Maldives", "Republic of Korea"], "type": "scatter", "uid": "3e3ccd6b-0969-4199-bdc7-34d74ef6460e", "x": [0.7641208189542725, 2.870047899570383, 1.7646290609427753, 0.8072297762995769, 0.691629866020365, 0.9381204394351735, -0.006129132168770718, 0.5844104968893692, 0.23783212359766498], "y": [2.1418284253898916, 3.154522711023835, 2.864548350865009, 1.8109693101932656, 2.0265428572880193, 2.5507622434168384, 2.6265081501172944, 5.081512499687632, 2.77895195187075]}, {"marker": {"color": "rgb(255,234,0)", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "Asia5", "text": ["Afghanistan", "Cyprus", "Georgia", "Iran (Islamic Republic of)", "Iraq", "Jordan", "Kuwait", "Lebanon", "Oman", "Pakistan", "Saudi Arabia", "Tajikistan", "United Arab Emirates", "Yemen"], "type": "scatter", "uid": "d71d7ab7-860a-440b-a735-8e133b5bc9e6", "x": [-0.5187362283538711, 1.1096046128329815, 0.370084776522889, -0.16505519369409327, -0.4843683929002223, 0.026303719127126406, 1.0325069333092165, -0.1268437004114436, 0.21315145331967061, -0.34910348987113765, -0.10022053368297267, -0.6961485504562095, -0.8548938602509599, -1.070187389705512], "y": [-1.4546206549531921, 0.3705331865728239, -0.8716671846477674, -1.0994537944471696, -0.19942009811612305, -0.9124448305221925, -0.3313888080663412, -0.8536854812691493, -0.2612514010189037, -1.1896534489904644, -0.22418943164201058, -1.4259635833460693, -0.581094298947789, -0.9182385101701513]}, {"marker": {"color": "rgb(150,0,90)", "line": {"width": 1}, "size": 9, "symbol": 1}, "mode": "markers", "name": "Eurpoe0", "text": [], "type": "scatter", "uid": "56c02356-09a9-40a0-903d- ...
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead

# %% [markdown]
# #### Region Level

# %% [markdown]
# ###### Add Region and Development Level

# %%
# Read in UN's country classification dataset. 
class_df = pd.read_excel("CLASS.xls",skiprows = 4)
class_df = class_df.drop(["Lending category","Other","Economy","x","x.1","X"], axis = 1)
class_df.head()
# Out:
#   Code                      Region         Income group
# 0    x                           x                    x
# 1  AFG                  South Asia           Low income
# 2  ALB       Europe & Central Asia  Upper middle income
# 3  DZA  Middle East & North Africa  Upper middle income
# 4  ASM         East Asia & Pacific  Upper middle income

# %%
# Convert to Country Code Alpha 3 for easier merging 
protein_group_df["Code"] = country_codes
protein_group_df["Code"].replace(manual_country_code_dict, inplace = True)
protein_group_df.head()
# Out:
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:5890: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                Country   Milk  Bovine meat  Sheep and goat meat  Pigmeat  \
# 0          Afghanistan   6.02         2.01                 2.02     0.00
# 1              Albania  29.67         9.18                 5.35     2.76
# 2              Algeria  13.78         2.18                 2.70     0.00
# 3               Angola   1.02         3.27                 0.44     2.34
# 4  Antigua and Barbuda  12.22         5.39                 0.60     3.26
#
#    Poultry  Eggs   Fish  Maize  Rice  Wheat   Rye  Barley  Pulses  \
# 0     0.79  0.32   0.02   0.57  2.89  37.12  0.00    0.72    1.56
# 1     4.91  3.24   1.50   0.36  1.22  33.71  0.13    0.03    3.06
# 2     2.30  2.09   1.23   3.09  0.50  43.03  0.00    2.61    4.55
# 3     5.55  0.51   4.14   8.80  1.55   8.46  0.00    0.00    5.23
# 4    18.59  1.30  13.11   0.39  2.15  13.39  0.00    0.00    1.66
#
#    Starchy roots  principal component 1  principal component 2      Continent  \
# 0           0.22              -0.518736              -1.454621           Asia
# 1           1.86               2.440719              -2.200208         Eurpoe
# 2           2.67               0.596646              -2.699386         Africa
# 3           7.13              -1.686584              -0.548387         Africa
# 4           0.86               0.845285               1.230920  North America
#
#    Continent_Cluster Code
# 0                  5  AFG
# 1                  2  ALB
# 2                  2  DZA
# 3                  0  AGO
# 4                  4  ATG

# %%
# Intermediate dataset combined using Country Code, which gives us information on country classification. 
protein_group_merged_df = protein_group_df.merge(class_df,how= "left", on="Code")
protein_group_merged_df.head()
# Out:
#                Country   Milk  Bovine meat  Sheep and goat meat  Pigmeat  \
# 0          Afghanistan   6.02         2.01                 2.02     0.00
# 1              Albania  29.67         9.18                 5.35     2.76
# 2              Algeria  13.78         2.18                 2.70     0.00
# 3               Angola   1.02         3.27                 0.44     2.34
# 4  Antigua and Barbuda  12.22         5.39                 0.60     3.26
#
#    Poultry  Eggs   Fish  Maize  Rice         ...           Barley  Pulses  \
# 0     0.79  0.32   0.02   0.57  2.89         ...             0.72    1.56
# 1     4.91  3.24   1.50   0.36  1.22         ...             0.03    3.06
# 2     2.30  2.09   1.23   3.09  0.50         ...             2.61    4.55
# 3     5.55  0.51   4.14   8.80  1.55         ...             0.00    5.23
# 4    18.59  1.30  13.11   0.39  2.15         ...             0.00    1.66
#
#    Starchy roots  principal component 1  principal component 2      Continent  \
# 0           0.22              -0.518736              -1.454621           Asia
# 1           1.86               2.440719              -2.200208         Eurpoe
# 2           2.67               0.596646              -2.699386         Africa
# 3           7.13              -1.686584              -0.548387         Africa
# 4           0.86               0.845285               1.230920  North America
#
#    Continent_Cluster Code                      Region         Income group
# 0                  5  AFG                  South Asia           Low income
# 1                  2  ALB       Europe & Central Asia  Upper middle income
# 2                  2  DZA  Middle East & North Africa  Upper middle income
# 3                  0  AGO          Sub-Saharan Africa  Lower middle income
# 4                  4  ATG   Latin America & Caribbean          High income
#
# [5 rows x 22 columns]

# %%
# Plot using matlablib on Region level.
colors_region = ['r', 'g', 'b','c','m','y','k']
pca_plot(colors_region,protein_group_merged_df,"Region")

region_cluster_labels, region_centers = perform_kmeans(X, 7)
protein_group_merged_df["Region_Cluster"] = region_cluster_labels
mark_shapes = ['s','d','p','h','o','*','x']

pca_kmeans_plot(colors_region,mark_shapes,protein_group_merged_df,"Region",region_centers)
# Out:
# ['South Asia' 'Europe & Central Asia' 'Middle East & North Africa'
#  'Sub-Saharan Africa' 'Latin America & Caribbean' 'East Asia & Pacific'
#  'North America']
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support 's' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support 'd' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support 'p' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support 'h' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support 'o' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support '*' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support 'x' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists

# %%
# Plot using plotly on Region level.

plot_plotly(protein_group_merged_df,"Region",region_centers,7,"Protein Foods",'')
# Out:
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:44: FutureWarning:
#
# elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <div>
#
#
#             <div id="f3ec8844-d550-44c4-963c-bcf0f15fbc6c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("f3ec8844-d550-44c4-963c-bcf0f15fbc6c")) {
#                     Plotly.newPlot(
#                         'f3ec8844-d550-44c4-963c-bcf0f15fbc6c',
#                         [{"marker": {"color": "rgb(150,0,90)", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "South Asia0", "text": [], "type": "scatter", "uid": "96bc038e-c33d-4f2e-ac4e-05754c23558b", "x": [], "y": []}, {"marker": {"color": "rgb(0,0,200)", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "South Asia1", "text": ["India", "Nepal"], "type": "scatter", "uid": "7eea4892-9c71-4db5-bd52-85819f3d4afe", "x": [-2.0959486456016725, -2.523104044473208], "y": [0.0243895474006073, -0.2713983772673335]}, {"marker": {"color": "rgb(10,152,255)", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "South Asia2", "text": [], "type": "scatter", "uid": "6d50ef4d-643c-41f8-9957-8e188c13df36", "x": [], "y": []}, {"marker": {"color": "rgb(44,255,150)", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "South Asia3", "text": [], "type": "scatter", "uid": "16f16cdf-364d-4131-a9ea-721e8899b3b2", "x": [], "y": []}, {"marker": {"color": "rgb(151,255,0)", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "South Asia4", "text": ["Bangladesh", "Sri Lanka"], "type": "scatter", "uid": "9f9fcf44-bc95-486b-981c-78157ecaa7c9", "x": [-2.962684688345844, -2.318022669366338], "y": [2.1555619555372973, 1.6227672996973552]}, {"marker": {"color": "rgb(255,234,0)", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "South Asia5", "text": ["Afghanistan", "Pakistan"], "type": "scatter", "uid": "8ca767de-0196-4f43-9dd8-7e5216343e8d", "x": [-0.5187362283538711, -0.34910348987113765], "y": [-1.4546206549531921, -1.1896534489904644]}, {"marker": {"color": "rgb(255,111,0)", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "South Asia6", "text": ["Maldives"], "type": "scatter", "uid": "764bb75b-47d4-4641-bc2f-c56b693cf75d", "x": [0.5844104968893692], "y": [5.081512499687632]}, {"marker": {"color": "rgb(150,0,90)", "line": {"width": 1}, "size": 9, "symbol": 1}, "mode": "markers", "name": "Europe & Central Asia0", "text": ["Albania", "Armenia", "Azerbaijan", "Greece", "Kazakhstan", "Kyrgyzstan", "Romania", "Turkey", "Turkmenistan", "Uzbekistan"], "type": "scatter", "uid": "921669b8-ec9f-4342-9602-d6324cbeec97", "x": [2.4407185523595496, 1.6741653766049829, 1.271725220438081, 2.1978078700150894, 2.001162515135617, 0.6016375020744401, 1.841996188386057, 0.8515084271113968, 1.8159607067811956, 1.014084698739387], "y": [-2.200207534746661, -1.0182527145102853, -2.2691708350668742, -1.4411654737196844, -1.6938835111056045, -2.1325228581750464, -1.0410906316902286, -1.8205513924393848, -3.1893678498892077, -1.8515767267611185]}, {"marker": {"color": "rgb(0,0,200)", "line": {"width": 1}, "size": 9, "symbol": 1}, "mode": "markers", "name": "Europe & Central Asia1", "text": [], "type": "scatter", "uid": "5b9c2c75-8cd2-4947-b4c0-13da8bf47d1a", "x": [], "y": []}, {"marker": {"color": "rgb(10,152,255)", "line": {"width": 1}, "size": 9, "symbol": 1}, "mode": "markers", "name": "Europe & Central Asia2", "text": ["Bulgaria", "Croatia", "Cyprus", "Hungary", "Serbia", "Slovakia"], "type": "scatter", "uid": "cd3d316b-08b2-4994-bc29-830e283d5815", "x": [0.9603595886425655, 1.5526797169539217, 1.1096046128329815, 1.6727698593509053, 0.6741377816947594, 1.494982790778646], "y": [-0.2495835333112877, 0.15156332152787577, 0.3705331865728239, 0.255626578987079, -0.6026848118923438, 0.0948578157074419]}, {"marker": {"color": "rgb(44,255,150)", "line": {"width": 1}, "size": 9, "symbol": 1}, "mode": "markers", "name": "Europe & Central Asia3", "text": ["Austria", "Belarus", "Belgium", "Czechia", "Denmark", "Estonia", "Finland", "France", "Germany", "Iceland", "Ireland", "Italy", "Latvia", "Lithuania", "Luxembourg", "Montenegro", "Netherlands", "Norway", "Poland", "Portugal", "Russian Federation", "Slovenia", "Spain", "Sweden", "Switzerland", "Ukraine", "United Kingdom"], "type": "scatter", "uid": "847b34bf-122c-4ade-927b ...

# %% [markdown]
# #### Income Level

# %%
# Plot using matlablib on Income level.

colors_income = ['r', 'g', 'b','c']
pca_plot(colors_income,protein_group_merged_df,"Income group")
mark_shapes_income = ['s','d','p','h']
income_cluster_labels, income_centers = perform_kmeans(X, 4)
protein_group_merged_df["Income group_Cluster"] = income_cluster_labels


pca_kmeans_plot(colors_income,mark_shapes_income,protein_group_merged_df,"Income group",income_centers)

# Output to csv 
protein_group_merged_df.to_csv("pca_protein.csv")
# Out:
# ['Low income' 'Upper middle income' 'Lower middle income' 'High income']
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support 's' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support 'd' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support 'p' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support 'h' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists

# %%
# Plotly on Income level
plot_plotly(protein_group_merged_df,"Income group",income_centers,4,"Protein Foods",'')
# Out:
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:44: FutureWarning:
#
# elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <div>
#
#
#             <div id="489176e5-b00f-4e57-98ec-73f21c030fe0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("489176e5-b00f-4e57-98ec-73f21c030fe0")) {
#                     Plotly.newPlot(
#                         '489176e5-b00f-4e57-98ec-73f21c030fe0',
#                         [{"marker": {"color": "rgb(150,0,90)", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "Low income0", "text": [], "type": "scatter", "uid": "1828ce7b-77e9-4bce-b34b-fad042372d77", "x": [], "y": []}, {"marker": {"color": "rgb(0,0,200)", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "Low income1", "text": ["Benin", "Burkina Faso", "Central African Republic", "Chad", "Democratic People's Republic of Korea", "Ethiopia", "Gambia", "Guinea", "Guinea-Bissau", "Haiti", "Liberia", "Madagascar", "Malawi", "Mali", "Mozambique", "Nepal", "Niger", "Rwanda", "Senegal", "Sierra Leone", "Togo", "Uganda", "United Republic of Tanzania", "Zimbabwe"], "type": "scatter", "uid": "79b73295-e4dd-4167-8c5e-c1c0027dd8f0", "x": [-2.574306620188047, -2.6988417531704827, -1.8351398693733723, -2.069051170726937, -2.551465145811014, -2.687635336603692, -1.6761351320939937, -2.5425623708509315, -2.335524291743871, -2.8472925218127094, -2.31255466064299, -2.644709869455552, -3.5596959019966756, -2.307225376399263, -2.8953867774802333, -2.523104044473208, -3.149529184881428, -3.4872450543097906, -2.127111850623701, -2.7516009915269657, -3.0254149402823947, -2.89415510149512, -2.9793875075126732, -2.283532440881736], "y": [-0.06101701118963632, -0.7570949947112842, -1.0903321355223372, -0.5123436434042392, 0.3474933616505065, -1.430444596711728, 0.5278721787493851, 1.0632374066055497, 1.1193271346434503, -0.29324096737323624, 1.255379695016391, 1.1315436072078517, -1.7461269870501357, -0.7200140202193901, -0.798282907030655, -0.2713983772673335, -1.4970933413683776, -1.7553359290743493, 0.8147949210622493, 1.4242765015759857, -0.7302448694536048, -1.0593593659050677, -1.0558610947394138, -0.7921952017482877]}, {"marker": {"color": "rgb(10,152,255)", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "Low income2", "text": [], "type": "scatter", "uid": "a5d1a4c8-827a-4f72-8be2-5842f9e227e7", "x": [], "y": []}, {"marker": {"color": "rgb(44,255,150)", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "Low income3", "text": ["Afghanistan", "Tajikistan", "Yemen"], "type": "scatter", "uid": "d8c1f33b-3e3c-4cfe-afbc-2f90ef7434de", "x": [-0.5187362283538711, -0.6961485504562095, -1.070187389705512], "y": [-1.4546206549531921, -1.4259635833460693, -0.9182385101701513]}, {"marker": {"color": "rgb(150,0,90)", "line": {"width": 1}, "size": 9, "symbol": 1}, "mode": "markers", "name": "Upper middle income0", "text": ["Albania", "Armenia", "Belarus", "Kazakhstan", "Montenegro", "Romania", "Russian Federation"], "type": "scatter", "uid": "b910ab79-4e65-445f-a815-bfbf4824b6c8", "x": [2.4407185523595496, 1.6741653766049829, 3.952101321516853, 2.001162515135617, 2.4095853816715658, 1.841996188386057, 2.6916004152646296], "y": [-2.200207534746661, -1.0182527145102853, 0.7652031841385577, -1.6938835111056045, -0.5105181230874344, -1.0410906316902286, -0.029226643120699985]}, {"marker": {"color": "rgb(0,0,200)", "line": {"width": 1}, "size": 9, "symbol": 1}, "mode": "markers", "name": "Upper middle income1", "text": ["Belize", "Botswana", "Cuba", "Guatemala", "Namibia", "Peru"], "type": "scatter", "uid": "c4894cf7-ab4e-4874-bdf4-3425b5bc45b8", "x": [-1.1199571355088507, -1.322867563938104, -1.4018342736743556, -1.7056440960682122, -1.6367561245530655, -1.129846991570885], "y": [0.20990102728536483, -0.9707486883297664, 0.11797398430783289, -0.9489861197311756, -0.8965507201708295, -0.003201503914810501]}, {"marker": {"color": "rgb(10,152,255)", "line": {"width": 1}, "size": 9, "symbol": 1}, "mode": "markers", "name": "Upper middle income2", "text": ["China, mainland", "Dominican Republic", "Ecuador", "Gabon", "Grenada", "Guyana", "Malaysia", "Maldives", "Saint Vincent and the Grenadines", "Samoa", "Suriname", "Thailand"], "type": "scatter", "uid": "b9802d70-3453-4fac-b48c-886cd4a2bf5b", "x": [0.8072297762995769, -1.0524901799530715, 0.013807238307056364, -0.75 ...

# %% [markdown]
# ### Analysis 2: PCA on protein foods + GDP + Urban/Rural ratio + permanent crops ratio

# %% [markdown]
# ###### Prepare Dataset
# ###### For this analysis, we groub bovine meat sheep goat pigmeat and poultry as a food group. Same for milk and egg.We then calculate a urban rural ration by dividing urban population with rural population. Last, we calculate a permanent crops ratio by dividing permanent crop area by total country area.
#
# ###### This results in a dataset with Bovine_Sheep_Pigmeat_Poultry, Cereals, Milk_Egg, Fish_x, Av 2011+2012+2013 extracted from WDI (constant 2010 Us dollars)Urban_Rural_ratio  Permenent_Crops_Ratio, Country, Code, Income group, Region, and Continent as columns.

# %%
protein_group_merged_df['Bovine_Sheep_Pigmeat_Poultry'] = protein_group_merged_df['Bovine meat']+protein_group_merged_df['Sheep and goat meat']+protein_group_merged_df['Pigmeat']+protein_group_merged_df['Poultry']
protein_group_merged_df['Milk_Egg'] = protein_group_merged_df['Milk']+protein_group_merged_df['Eggs']
protein_group_merged_master_df = protein_group_merged_df.merge(master_df,how="left",on="Country")
protein_group_merged_master_df['Urban_Rural_ratio'] = protein_group_merged_master_df["Urban population"]/protein_group_merged_master_df["Rural population"]
protein_group_merged_master_df['Permenent_Crops_Ratio'] = protein_group_merged_master_df['Permanent crops area']/ protein_group_merged_master_df['Total area of the country (excl. coastal waters)']
# protein_group_merged_final_master_df = protein_group_merged_master_df.merge(principalDf,how="left",on ="Country")
socio_cols = ['Bovine_Sheep_Pigmeat_Poultry','Cereals','Milk_Egg','Fish_x'
              ,' Av 2011+2012+2013 extracted from WDI (constant 2010 US$)'
              ,'Urban_Rural_ratio','Permenent_Crops_Ratio']

country_cols = ['Country','Code','Income group','Region','Continent']

desired_cols = socio_cols + country_cols

socio_pca_df = protein_group_merged_master_df[desired_cols]
socio_pca_df.head()
# Out:
#    Bovine_Sheep_Pigmeat_Poultry  Cereals  Milk_Egg  Fish_x  \
# 0                          4.82    41.39      6.34    0.02
# 1                         22.20    35.48     32.91    1.50
# 2                          7.18    49.25     15.87    1.23
# 3                         11.60    19.00      1.53    4.14
# 4                         27.84    16.60     13.52   13.11
#
#     Av 2011+2012+2013 extracted from WDI (constant 2010 US$)  \
# 0                                         572.815028
# 1                                        4271.534293
# 2                                        4555.191581
# 3                                        3709.969541
# 4                                       11929.279270
#
#    Urban_Rural_ratio  Permenent_Crops_Ratio              Country Code  \
# 0           0.328817               0.001838          Afghanistan  AFG
# 1           1.429285               0.026748              Albania  ALB
# 2           2.395336               0.003880              Algeria  DZA
# 3           0.528939               0.002326               Angola  AGO
# 4           0.300981               0.022727  Antigua and Barbuda  ATG
#
#           Income group                      Region      Continent
# 0           Low income                  South Asia           Asia
# 1  Upper middle income       Europe & Central Asia         Eurpoe
# 2  Upper middle income  Middle East & North Africa         Africa
# 3  Lower middle income          Sub-Saharan Africa         Africa
# 4          High income   Latin America & Caribbean  North America

# %%
# Missing Values 
socio_pca_df[pd.isnull(socio_pca_df).any(axis=1)]
# Out:
#      Bovine_Sheep_Pigmeat_Poultry  Cereals  Milk_Egg  Fish_x  \
# 17                          38.51    14.63     12.07   12.40
# 32                          48.46    19.07     13.34   17.38
# 33                          34.35    18.57      9.42   15.11
# 35                          25.05    22.13      7.63    8.98
# 44                           2.55    27.69      1.78    2.58
# 46                           6.57    37.06      4.65    1.01
# 57                          34.92    20.25     11.51   13.29
# 112                         27.44    22.12     14.43    7.40
# 127                         12.77    28.02     16.60    3.63
# 153                         12.46    27.89     15.76    1.43
#
#       Av 2011+2012+2013 extracted from WDI (constant 2010 US$)  \
# 17                                         82266.93602
# 32                                         34325.77821
# 33                                         66970.48546
# 35                                                 NaN
# 44                                                 NaN
# 46                                                 NaN
# 57                                                 NaN
# 112                                                NaN
# 127                                                NaN
# 153                                                NaN
#
#      Urban_Rural_ratio  Permenent_Crops_Ratio  \
# 17                 NaN                    NaN
# 32                 NaN                    NaN
# 33                 NaN                    NaN
# 35                 NaN                    NaN
# 44            1.513552               0.019081
# 46            3.036647               0.000000
# 57                 NaN                    NaN
# 112                NaN                    NaN
# 127           0.630905               0.087149
# 153           1.370286               0.014002
#
#                                    Country Code         Income group  \
# 17                                 Bermuda  BMU          High income
# 32                    China, Hong Kong SAR  HKG          High income
# 33                        China, Macao SAR  MAC          High income
# 35               China, Taiwan Province of  TWN          High income
# 44   Democratic People's Republic of Korea  PRK           Low income
# 46                                Djibouti  DJI  Lower middle income
# 57                        French Polynesia  PYF          High income
# 112                          New Caledonia  NCL          High income
# 127                    Republic of Moldova  MDA  Lower middle income
# 153                        North Macedonia  MKD  Upper middle income
#
#                          Region      Continent
# 17                North America  North America
# 32          East Asia & Pacific           Asia
# 33          East Asia & Pacific           Asia
# 35          East Asia & Pacific           Asia
# 44          East Asia & Pacific           Asia
# 46   Middle East & North Africa         Africa
# 57          East Asia & Pacific      Australia
# 112         East Asia & Pacific      Australia
# 127       Europe & Central Asia         Eurpoe
# 153       Europe & Central Asia         Europe

# %%
# Since missing values cannot be processing using pca, we will simply drop them.

socio_pca_dropped_df = socio_pca_df.dropna()

socio_scaled = StandardScaler().fit_transform(socio_pca_dropped_df[socio_cols])

# %% [markdown]
# ###### PCA

# %%
principalComponents_socio = pca.fit_transform(socio_scaled)

# principalDf_socio = pd.DataFrame(data = principalComponents_socio
#              , columns = ['principal component 1', 'principal component 2'])
pc_socio_1,pc_socio_2 = zip(*principalComponents_socio)
socio_pca_dropped_df["principal component 1"] = pc_socio_1
socio_pca_dropped_df["principal component 2"] = pc_socio_2

socio_pca_dropped_df = socio_pca_dropped_df.rename({"Income group_y":"Income group","Region_y":"Region","Continent_x":"Continent"}, axis = 1)
X_socio = socio_pca_dropped_df[["principal component 1","principal component 2"]].values

# %% [markdown]
# #### Continent Level

# %%
colors_region = ['r', 'g', 'b','c','m','y']
pca_plot(colors_region,socio_pca_dropped_df,"Continent")

continent_cluster_labels_socio, continent_centers_socio = perform_kmeans(X_socio, 6)
socio_pca_dropped_df["Continent_Cluster"] = continent_cluster_labels_socio
mark_shapes = ['s','d','p','h','o','*','x']

pca_kmeans_plot(colors_region,mark_shapes,socio_pca_dropped_df,"Continent",continent_centers_socio)
# Out:
# ['Asia' 'Eurpoe' 'Africa' 'North America' 'South America' 'Australia']
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support 's' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support 'd' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support 'p' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support 'h' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support 'o' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support '*' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists

# %%
plot_plotly(socio_pca_dropped_df,"Continent",continent_centers_socio,6,"Socioeconomic + Foods",'')
# Out:
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:44: FutureWarning:
#
# elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <div>
#
#
#             <div id="52904d2c-3c10-4105-b369-868ed9e291d1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("52904d2c-3c10-4105-b369-868ed9e291d1")) {
#                     Plotly.newPlot(
#                         '52904d2c-3c10-4105-b369-868ed9e291d1',
#                         [{"marker": {"color": "rgb(150,0,90)", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "
", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "Asia5", "text": ["Israel", "Kuwait"], "type": "scatter", "uid": "ccd6ca29-85db-427b-bc63-26f40ebb6328", "x": [2.914598912157268, 2.7894646431280834], "y": [-0.34767878158871257, -0.8598360855517289]}, {"marker": {"color": "rgb(150,0,90)", "line": {"width": 1}, "size": 9, "symbol": 1}, "mode": "markers", "name": "Eurpoe0", "text": [], "type": "scatter", "uid": "cd692bcf-d781-439e-9954-3a787988390f", "x": [], "y": []}, {"marker": {"color": "rgb(0,0,200)", "line": {"width": 1}, "size": 9, "symbol": 1}, "mode": "markers", "name": "Eurpoe1", "text": ["Albania", "Belarus", "Bulgaria", "Croatia", "Czechia", "Estonia", "Hungary", "Latv ...

# %% [markdown]
# #### Region Level

# %%
colors_region = ['r', 'g', 'b','c','m','y','k']
pca_plot(colors_region,socio_pca_dropped_df,"Region")

region_cluster_labels_socio, region_centers_socio = perform_kmeans(X_socio, 7)
socio_pca_dropped_df["Region_Cluster"] = region_cluster_labels_socio
mark_shapes = ['s','d','p','h','o','*','x']

pca_kmeans_plot(colors_region,mark_shapes,socio_pca_dropped_df,"Region",region_centers_socio)
# Out:
# ['South Asia' 'Europe & Central Asia' 'Middle East & North Africa'
#  'Sub-Saharan Africa' 'Latin America & Caribbean' 'East Asia & Pacific'
#  'North America']
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support 's' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support 'd' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support 'p' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support 'h' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support 'o' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support '*' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support 'x' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists

# %%
plot_plotly(socio_pca_dropped_df,"Region",region_centers_socio,7, "Socioeconomic + Foods",'')
# Out:
# <div>
#
#
#             <div id="af39d6b9-62c7-4f2d-b9bb-6385eabe83de" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("af39d6b9-62c7-4f2d-b9bb-6385eabe83de")) {
#                     Plotly.newPlot(
#                         'af39d6b9-62c7-4f2d-b9bb-6385eabe83de',
#                         [{"marker": {"color": "rgb(150,0,90)", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "South Asia0", "text": ["Maldives"], "type": "scatter", "uid": "3948283f-6b08-4160-926f-5eb1b92cd054", "x": [0.4958044359188891], "y": [6.065440784985911]}, {"marker": {"color": "rgb(0,0,200)", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "South Asia1", "text": [], "type": "scatter", "uid": "33d5aeff-8d03-41bd-92da-65a2b6a95682", "x": [], "y": []}, {"marker": {"color": "rgb(10,152,255)", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "South Asia2", "text": ["Afghanistan", "India", "Nepal", "Pakistan"], "type": "scatter", "uid": "54b05d00-ea9b-470a-9fc3-591eee448ac0", "x": [-1.697410120640752, -1.6344003841231114, -1.7785324979852302, -0.7191219289529936], "y": [-1.5434506618250943, -0.5238917455834444, -1.2115414050601474, -0.9255942002221457]}, {"marker": {"color": "rgb(44,255,150)", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "South Asia3", "text": [], "type": "scatter", "uid": "68504600-d191-41d1-a776-ebc33074df88", "x": [], "y": []}, {"marker": {"color": "rgb(151,255,0)", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "South Asia4", "text": ["Bangladesh", "Sri Lanka"], "type": "scatter", "uid": "381bb117-fec9-45e2-a69a-fa2ed25170b2", "x": [-2.0184911071699387, -1.894440357050651], "y": [-0.13706821892481022, 1.5859720350300157]}, {"marker": {"color": "rgb(255,234,0)", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "South Asia5", "text": [], "type": "scatter", "uid": "d4c2ed7a-0a8f-4166-8bba-0d9675ba1ef9", "x": [], "y": []}, {"marker": {"color": "rgb(255,111,0)", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "South Asia6", "text": [], "type": "scatter", "uid": "f4e36003-aaee-4fa4-a959-bbe89d42a012", "x": [], "y": []}, {"marker": {"color": "rgb(150,0,90)", "line": {"width": 1}, "size": 9, "symbol": 1}, "mode": "markers", "name": "Europe & Central Asia0", "text": [], "type": "scatter", "uid": "fade9d55-8dbb-4340-aa3e-19735da3d5c5", "x": [], "y": []}, {"marker": {"color": "rgb(0,0,200)", "line": {"width": 1}, "size": 9, "symbol": 1}, "mode": "markers", "name": "Europe & Central Asia1", "text": ["Cyprus", "Portugal", "Spain"], "type": "scatter", "uid": "171a19cd-7f8f-42dd-88d8-00c7573cdc66", "x": [1.1213910251970858, 1.4030474837653042, 1.7422920797086738], "y": [0.6197199705027545, 1.1920547703468016, 1.5437004215534584]}, {"marker": {"color": "rgb(10,152,255)", "line": {"width": 1}, "size": 9, "symbol": 1}, "mode": "markers", "name": "Europe & Central Asia2", "text": ["Azerbaijan", "Bosnia and Herzegovina", "Georgia", "Kyrgyzstan", "Tajikistan", "Turkey", "Turkmenistan", "Uzbekistan"], "type": "scatter", "uid": "e44d35a9-d9b7-4117-a1b4-299a0478752c", "x": [-0.7716116820685527, -0.5742328253056509, -0.8531881018453802, -0.4132241408937572, -1.6050790260876788, -0.1996661610381046, -0.1789231253295809, -0.8268689731421277], "y": [-2.0334849113621662, -1.154788450463492, -1.3703426580556415, -1.4197472397963942, -0.8856664360915395, -1.6227730410045826, -1.8493517879497932, -1.5877997108141453]}, {"marker": {"color": "rgb(44,255,150)", "line": {"width": 1}, "size": 9, "symbol": 1}, "mode": "markers", "name": "Europe & Central Asia3", "text": ["Albania", "Belarus", "Croatia", "Czechia", "Estonia", "Greece", "Hungary", "Italy", "Kazakhstan", "Latvia", "Lithuania", "Montenegro", "Poland", "Romania", "Russian Federation", "Slovenia"], "type": "scatter", "uid": "f1dbba55-6a4a-4e86-a319-255c71ac9beb", "x": [0.9365399612021017, 1.0116982666771925, 0.6673753823898034, 1.1547146971486633, 1.050427792705692, 1.4459549850913607, 0.6232839978584427, 1.487044666098583, 1.0276342929177762, 0.8151694825992627, 1.733589864370219, 1.2920439726088986, 0.7881043388377904, 0.4538360103147787, 0.873234334280595, 1.1817367677991106], "y": [-1.20168920 ...
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead

# %% [markdown]
# #### Development Level

# %%
colors_region = ['r', 'g', 'b','c']
pca_plot(colors_region,socio_pca_dropped_df,"Income group")

income_cluster_labels_socio, income_centers_socio = perform_kmeans(X_socio, 4)
socio_pca_dropped_df["Income group_Cluster"] = income_cluster_labels_socio
mark_shapes = ['s','d','p','h']

pca_kmeans_plot(colors_region,mark_shapes,socio_pca_dropped_df,"Income group",income_centers_socio)

socio_pca_dropped_df.to_csv("pca_socio.csv")
# Out:
# ['Low income' 'Upper middle income' 'Lower middle income' 'High income']
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support 's' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support 'd' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support 'p' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support 'h' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists

# %%
plot_plotly(socio_pca_dropped_df,"Income group",income_centers_socio,4,"Socioeconomic + Foods",'')
# Out:
# <div>
#
#
#             <div id="198ff55b-4e53-4092-927b-78780f1583c2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("198ff55b-4e53-4092-927b-78780f1583c2")) {
#                     Plotly.newPlot(
#                         '198ff55b-4e53-4092-927b-78780f1583c2',
#                         [{"marker": {"color": "rgb(150,0,90)", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "Low income0", "text": ["Haiti", "Rwanda", "Sierra Leone", "Uganda"], "type": "scatter", "uid": "a5d4c465-fad4-4432-a51e-6be8e382b29c", "x": [-1.7527538191992473, -1.8783042629902822, -1.6431078242186399, -1.681880805191861], "y": [1.0337133515907215, 1.5130943997920991, 0.7477848395791405, 1.4444051743624156]}, {"marker": {"color": "rgb(0,0,200)", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "Low
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead

# %% [markdown]
# ### Analysis 3: PCA on protein foods + GDP + Urban/Rural ratio + permanent crops ratio

# %% [markdown]
# ###### Prepare the datasets

# %%
# http://apps.who.int/gho/data/node.main.CHILDSTUNTED?lang=en
stunting_df = pd.read_csv("NUTRITION_HA_2.csv", skiprows=1)
overweight_df = pd.read_csv("NUTRITION_WH2.csv",skiprows=1)

# %%
stunting_df.head()
# Out:
#        Country        Year   Both sexes
# 0  Afghanistan        2013         40.9
# 1  Afghanistan        2004         59.3
# 2  Afghanistan        1997         53.2
# 3      Albania   2017-2018         11.3
# 4      Albania   2008-2009         23.2

# %%
overweight_df.head()
# Out:
#        Country        Year   Both sexes
# 0  Afghanistan        2013          5.4
# 1  Afghanistan        2004          4.6
# 2  Afghanistan        1997          6.5
# 3      Albania   2017-2018         16.4
# 4      Albania   2008-2009         23.2

# %%
def get_nearest_year(df,name):
    """
    This function takes in a dataframe, and split the year range to half. 
    It keeps the start year. Then finds the latest year and adds it to the result dataframe. 
    """
    result_df = pd.DataFrame()
    country_list = df["Country"].unique().tolist()
    country_code_new = []
    df[[1,2]] = df['Year'].str.split('-',n=1, expand=True)
    df = df.drop(["Year",2], axis = 1)
    df = df.rename({1:"year"," Both sexes":name},axis = 1)
    df["year"] = df["year"].astype(int)
    for i in country_list:
        try:
            code = country_name_to_country_alpha3(i)
            country_code_new.append(code)
        except:
            code = i 
            country_code_new.append(code)
        result_df = result_df.append(df.loc[[df[df["Country"] == i]["year"].idxmax()]])
    return result_df,country_code_new

# %%
result_stunting_df,country_code_new_stunting = get_nearest_year(stunting_df,"stunting(percentage)")
result_overweight_df,country_code_new_overweight = get_nearest_year(overweight_df,"overweight(percentage)")

# get country code for both datasets for easier merging later
result_stunting_df["Code"] = country_code_new_stunting
result_overweight_df["Code"] = country_code_new_overweight

# Replace the missing ones with manully inputted country codes. 
result_stunting_df["Code"] = result_stunting_df["Code"].replace(manual_country_code_dict)
result_overweight_df["Code"] = result_overweight_df["Code"].replace(manual_country_code_dict)

# %%
# We merge this health dataset with the intermediate data set from previous anaylsis. 
protein_group_merged_stunting_master_df = socio_pca_df.merge(result_stunting_df,how="left", on="Code")
protein_group_merged_stunting_ow_master_df = protein_group_merged_stunting_master_df.merge(result_overweight_df,how="left", on="Code")

# %%
# Check the missing values here. 
protein_group_merged_stunting_ow_master_df[protein_group_merged_stunting_ow_master_df["stunting(percentage)"].isna()]
# Out:
#      Bovine_Sheep_Pigmeat_Poultry  Cereals  Milk_Egg  Fish_x  \
# 4                           27.84    16.60     13.52   13.11
# 8                           29.81    26.92     25.94    3.99
# 10                          37.36    13.89     11.01    7.47
# 14                          19.85    26.07     27.26    6.54
# 17                          38.51    14.63     12.07   12.40
# 28                          31.11    25.42     16.96    5.55
# 32                          48.46    19.07     13.34   17.38
# 33                          34.35    18.57      9.42   15.11
# 35                          25.05    22.13      7.63    8.98
# 40                          18.32    25.39     21.60    5.88
# 71            2.399931               0.019564
# 72           15.522843               0.000000
# 77            1.566100               0.000142
# 78           10.473920               0.041414
# 79            2.320216               0.081038
# 89            2.065282               0.000931
# 93            1.977451               0.004870
# 94            7.190769               0.006062
# 100          28.020690               0.040625
# 111           7.457935               0.008618
# 112                NaN                    NaN
# 113           6.160256               0.002667
# 117           3.847195               0.000114
# 125           1.623853               0.079384
# 129           2.796114               0.000936
# 131           0.480158               0.003846
# 133           0.981149               0.076923
# 140           1.195784               0.004119
# 141           1.001944               0.025639
# 144           3.701214               0.098213
# 149           5.709564               0.000112
# 150           2.762061               0.005909
# 162           7.061594               0.004737
# 163           3.991454               0.001888
#
#                             Country_x Code         Income group  \
# 4                 Antigua and Barbuda  ATG          High income
# 8                             Austria  AUT          High income
# 10                            Bahamas  BHS          High income
# 14                            Belgium  BEL          High income
# 17                            Bermuda  BMU          High income
# 28                             Canada  CAN          High income
# 32               China, Hong Kong SAR  HKG          High income
# 33                   China, Macao SAR  MAC          High income
# 35          China, Taiwan Province of  TWN          High income
# 40                            Croatia  HRV          High income
# 42                             Cyprus  CYP          High income
# 45                            Denmark  DNK          High income
# 47                           Dominica  DMA  Upper middle income
# 52                            Estonia  EST          High income
# 55                            Finland  FIN          High income
# 56                             France  FRA          High income
# 57                   French Polynesia  PYF          High income
# 63                             Greece  GRC          High income
# 64                            Grenada  GRD  Upper middle income
# 71                            Hungary  HUN          High income
# 72                            Iceland  ISL          High income
# 77                            Ireland  IRL          High income
# 78                             Israel  ISR          High income
# 79                              Italy  ITA          High income
# 89                             Latvia  LVA          High income
# 93                          Lithuania  LTU          High income
# 94                         Luxembourg  LUX          High income
# 100                             Malta  MLT          High income
# 111                       Netherlands  NLD          High income
# 112                     New Caledonia  NCL          High income
# 113                       New Zealand  NZL          High income
# 117                            Norway  NOR          High income
# 125                          Portugal  PRT          High income
# 129                Russian Federation  RUS  Upper middle income
# 131             Saint Kitts and Nevis  KNA          High income
# 133  Saint Vincent and the Grenadines  VCT  Upper middle income
# 140                          Slovakia  SVK          High income
# 141                          Slovenia  SVN          High income
# 144                             Spain  ESP          High income
# 149                            Sweden  SWE          High income
# 150                       Switzerland  CHE          High income
# 162              United Arab Emirates  ARE          High income
# 163                    United Kingdom  GBR          High income
#
#                          Region      Continent Country_y  \
# 4     Latin America & Caribbean  North America       NaN
# 8         Europe & Central Asia         Eurpoe       NaN
# 10    Latin America & Caribbean  North America       NaN
# 14        Europe & Central Asia         Eurpoe       NaN
# 17                North America  North America       NaN
# 28                North America  North America       NaN
# 32          East Asia & Pacific           Asia       NaN
# 33          East Asia & Pacific           Asia       NaN
# 35          East Asia & Pacific           Asia       NaN
# 40        Europe & Central Asia         Eurpoe       NaN
# 42        Europe & Central Asia           Asia       NaN
# 45        Europe & Central Asia         Eurpoe       NaN
# 47    Latin America & Caribbean  North America       NaN
# 52        Europe & Central Asia         Eurpoe       NaN
# 55        Europe & Central Asia         Eurpoe       NaN
# 56        Europe & Central Asia         Eurpoe       NaN
# 57          East Asia & Pacific      Australia       NaN
# 131                   NaN     NaN     NaN                     NaN     NaN
# 133                   NaN     NaN     NaN                     NaN     NaN
# 140                   NaN     NaN     NaN                     NaN     NaN
# 141                   NaN     NaN     NaN                     NaN     NaN
# 144                   NaN     NaN     NaN                     NaN     NaN
# 149                   NaN     NaN     NaN                     NaN     NaN
# 150                   NaN     NaN     NaN                     NaN     NaN
# 162                   NaN     NaN     NaN                     NaN     NaN
# 163                   NaN     NaN     NaN                     NaN     NaN

# %%
# We are going to drop the missing values for now. 
protein_group_merged_stunting_ow_master_df = protein_group_merged_stunting_ow_master_df.dropna(subset=['stunting(percentage)','overweight(percentage)'])

# %%
# We only keep the useful columns here
socio_health_cols = socio_cols+['stunting(percentage)','overweight(percentage)']
socio_health_cols.remove(" Av 2011+2012+2013 extracted from WDI (constant 2010 US$)")
socio_health_cols.remove("Urban_Rural_ratio")
socio_health_cols.remove("Permenent_Crops_Ratio")
protein_group_merged_stunting_ow_master_df = protein_group_merged_stunting_ow_master_df[socio_health_cols + country_cols]
# protein_group_merged_stunting_ow_master_df.rename({"Income group_y":"Income group","Fish_x":"Fish","Region_y":"Region"},axis = 1,inplace = True)

# %%
# Overview of our dataset. 
protein_group_merged_stunting_ow_master_df.head()
# Out:
#    Bovine_Sheep_Pigmeat_Poultry  Cereals  Milk_Egg  Fish_x  \
# 0                          4.82    41.39      6.34    0.02
# 1                         22.20    35.48     32.91    1.50
# 2                          7.18    49.25     15.87    1.23
# 3                         11.60    19.00      1.53    4.14
# 5                         43.03    27.19     17.95    1.95
#
#    stunting(percentage)  overweight(percentage)      Country Code  \
# 0                  40.9                     5.4  Afghanistan  AFG
# 1                  11.3                    16.4      Albania  ALB
# 2                  11.7                    12.4      Algeria  DZA
# 3                  37.6                     3.4       Angola  AGO
# 5                   8.2                     9.9    Argentina  ARG
#
#           Income group                      Region      Continent
# 0           Low income                  South Asia           Asia
# 1  Upper middle income       Europe & Central Asia         Eurpoe
# 2  Upper middle income  Middle East & North Africa         Africa
# 3  Lower middle income          Sub-Saharan Africa         Africa
# 5          High income   Latin America & Caribbean  South America

# %% [markdown]
# ###### PCA

# %%
health_scaled = StandardScaler().fit_transform(protein_group_merged_stunting_ow_master_df[socio_health_cols])

# %%
# Merge the calculated PCA value back to our dataset. 

principalComponents_health = pca.fit_transform(health_scaled)
pc_health_1,pc_health_2 = zip(*principalComponents_health)
protein_group_merged_stunting_ow_master_df["principal component 1"] = pc_health_1
protein_group_merged_stunting_ow_master_df["principal component 2"] = pc_health_2
protein_group_merged_stunting_ow_master_df = protein_group_merged_stunting_ow_master_df.rename({"Income group_y":"Income group","Region_y":"Region"}, axis = 1)
X_health = protein_group_merged_stunting_ow_master_df[["principal component 1","principal component 2"]].values

# %% [markdown]
# #### Continent Level

# %%
colors_region = ['r', 'g', 'b','c','m','y']
pca_plot(colors_region,protein_group_merged_stunting_ow_master_df,"Continent")

continent_cluster_labels_health, continent_centers_health = perform_kmeans(X_health, 6)
protein_group_merged_stunting_ow_master_df["Continent_Cluster"] = continent_cluster_labels_health
mark_shapes = ['s','d','p','h','o','*','x']

pca_kmeans_plot(colors_region,mark_shapes,protein_group_merged_stunting_ow_master_df,"Continent",continent_centers_health)
# Out:
# ['Asia' 'Eurpoe' 'Africa' 'South America' 'Australia' 'North America'
#  'Europe']
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support
", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "Asia5", "text": ["Afghanistan", "Bangladesh", "India", "Indonesia", "Iraq", "Lao People's Democratic Republic", "Nepal", "Pakistan", "Tajikistan", "Yemen"], "type": "scatter", "uid": "d390fe96-4894-48f7-a525-279d418928e1", "x": [-1.6286069371877256, -2.2409545590300173, -1.8172410339270009, -1.2244325355736267, -0.3460984349162033, -2.3522081929660503, -1.900972514990409, -0.8100127274653133, -0.9230762246405538, -2.098506755251877], "y": [-1.6082628900777034, -0.5048382070232365, -0.6862803634547778, -0.5226257798933716, -1.669075264532189, -0.42965894552206796, -1.0834143900466484, -0.6370180009457593, -0.48544826461939583, -1.1489137431904306]}, {"marker": {"color": "rgb(150,0,90)", "line": {"width": 1}, "size": 9, "symbol": 1}, "mode": "markers", "name": "Eurpoe0", "text": [], "type": "scatter", "uid": "dd436e1d-7729-49c0-a8b3-cff372fb11ed", "x": [], "y": []}, {"marker": {"color": "rgb(0,0,200)", "line": {"width": 1}, "size": 9, "symbol": 1}, "mode": "markers", "name": "Eurpoe1", "text": ["Albania", "Belarus", "Czechia", "Germany", "Montenegro", "Serbia"], "type": "scatter", "uid": "4c225286-8349-4ec2-8856-f5f78c0ec9c7", "x": [3.3627701574307998, 2.4535958860306226, 1.92005 ...
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead

# %% [markdown]
# #### Region Level

# %%
colors_region = ['r', 'g', 'b','c','m','y','k']
pca_plot(colors_region,protein_group_merged_stunting_ow_master_df,"Region")

region_cluster_labels_health, region_centers_health = perform_kmeans(X_health, 7)
protein_group_merged_stunting_ow_master_df["Region_Cluster"] = region_cluster_labels_health
mark_shapes = ['s','d','p','h','o','*','x']

pca_kmeans_plot(colors_region,mark_shapes,protein_group_merged_stunting_ow_master_df,"Region",region_centers_health)
# Out:
# ['South Asia' 'Europe & Central Asia' 'Middle East & North Africa'
#  'Sub-Saharan Africa' 'Latin America & Caribbean' 'East Asia & Pacific'
#  'North America']
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support 's' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support 'd' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support 'p' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support 'h' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support 'o' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support '*' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support 'x' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists

# %%
plot_plotly(protein_group_merged_stunting_ow_master_df,"Region",region_centers_health,7,"Health + Foods",'')
# Out:
# <div>
#
#
#             <div id="ebeb8ccb-e32f-4579-bdf8-efdc7cd54b44" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ebeb8ccb-e32f-4579-bdf8-efdc7cd54b44")) {
#                     Plotly.newPlot(
#                         'ebeb8ccb-e32f-4579-bdf8-efdc7cd54b44',
#                         [{"marker": {"color": "rgb(150,0,90)", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "South Asia0", "text": [], "type": "scatter", "uid": "94b007f3-b7f9-4085-8ddd-cac2cb3bc46c", "x": [], "y": []}, {"marker": {"color": "rgb(0,0,200)", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "South Asia1", "text": ["Afghanistan", "Pakistan"], "type": "scatter", "uid": "951d576d-afe1-4bb4-a922-05b72e4582da", "x": [-1.6286069371877256, -0.8100127274653133], "y": [-1.6082628900777034, -0.6370180009457593]}, {"marker": {"color": "rgb(10,152,255)", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "South Asia2", "text": [], "type": "scatter", "uid": "029c8d26-f0ca-439c-9f9f-fc352287e2bb", "x": [], "y": []}, {"marker": {"color": "rgb(44,255,150)", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "South Asia3", "text": ["Sri Lanka"], "type": "scatter", "uid": "c75740a6-7c1a-448e-9f5e-941d55dcf0a9", "x": [-1.2796589799882865], "y": [0.5798619356011306]}, {"marker": {"color": "rgb(151,255,0)", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "South Asia4", "text": [], "type": "scatter", "uid": "a4c5df56-5d57-4343-b15e-a5253d0ce6a6", "x": [], "y": []}, {"marker": {"color": "rgb(255,234,0)", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "South Asia5", "text": ["Bangladesh", "India", "Nepal"], "type": "scatter", "uid": "c69efa21-b936-43dc-896a-2ef87bc8f078", "x": [-2.2409545590300173, -1.8172410339270009, -1.900972514990409], "y": [-0.5048382070232365, -0.6862803634547778, -1.0834143900466484]}, {"marker": {"color": "rgb(255,111,0)", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "South Asia6", "text": ["Maldives"], "type": "scatter", "uid": "714e0e13-096e-48b9-a449-e562e0622ad1", "x": [-0.17820783787282754], "y": [5.495113156296888]}, {"marker": {"color": "rgb(150,0,90)", "line": {"width": 1}, "size": 9, "symbol": 1}, "mode": "markers", "name": "Europe & Central Asia0", "text": ["Republic of Moldova"], "type": "scatter", "uid": "6922d255-b296-4a28-8dec-3a5c8a47eaf0", "x": [0.8617906982983496], "y": [0.23553672866514286]}, {"marker": {"color": "rgb(0,0,200)", "line": {"width": 1}, "size": 9, "symbol": 1}, "mode": "markers", "name": "Europe & Central Asia1", "text": ["Tajikistan"], "type": "scatter", "uid": "73c57f7c-31af-4839-ac8d-9cb16ddddb7e", "x": [-0.9230762246405538], "y": [-0.48544826461939583]}, {"marker": {"color": "rgb(10,152,255)", "line": {"width": 1}, "size": 9, "symbol": 1}, "mode": "markers", "name": "Europe & Central Asia2", "text": ["Azerbaijan", "Bosnia and Herzegovina", "Georgia", "Kyrgyzstan", "Romania", "Turkey", "Turkmenistan", "Uzbekistan"], "type": "scatter", "uid": "1b5fee3e-2208-450d-9443-5d432681d395", "x": [1.1832325392782295, 1.8208455723420176, 1.6597096905416338, 1.0596441016188023, 1.936612327344024, 1.5276696115087083, 1.2191538153782187, 0.8218622093341498], "y": [-2.573300512669042, -1.5002954340285637, -2.018465573063608, -0.9944063593491036, -1.1894143737462994, -1.9560327427588853, -1.2785144691409283, -1.6558426434216311]}, {"marker": {"color": "rgb(44,255,150)", "line": {"width": 1}, "size": 9, "symbol": 1}, "mode": "markers", "name": "Europe & Central Asia3", "text": [], "type": "scatter", "uid": "6f3b3409-a6be-4ea5-a564-428c11958019", "x": [], "y": []}, {"marker": {"color": "rgb(151,255,0)", "line": {"width": 1}, "size": 9, "symbol": 1}, "mode": "markers", "name": "Europe & Central Asia4", "text": ["Albania", "Armenia", "Belarus", "Bulgaria", "Czechia", "Germany", "Kazakhstan", "Montenegro", "Serbia", "Republic of North Macedonia", "Ukraine"], "type": "scatter", "uid": "c47a8b0c-ea4e-46b1-ba3d-c6b803b7e438", "x": [3.3627701574307998, 2.0905241543146347, 2.4535958860306226, 1.8647605289388334, 1.9200550463012729, 2.5611584815555704, 2.5095443715772423, 3.9935883827610583, 1.8631994253077526, 1.4987785155700 ...
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead

# %% [markdown]
# #### Development Level

# %%
colors_region = ['r', 'g', 'b','c']
pca_plot(colors_region,protein_group_merged_stunting_ow_master_df,"Income group")

income_cluster_labels_health, income_centers_health = perform_kmeans(X_health, 4)
protein_group_merged_stunting_ow_master_df["Income group_Cluster"] = income_cluster_labels_health
mark_shapes = ['s','d','p','h']

pca_kmeans_plot(colors_region,mark_shapes,protein_group_merged_stunting_ow_master_df,"Income group",income_centers_health)

protein_group_merged_stunting_ow_master_df.to_csv("pca_health.csv")
# Out:
# ['Low income' 'Upper middle income' 'Lower middle income' 'High income']
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support 's' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\legend.py:798: UserWarning:
#
# Legend does not support 
line": {"width": 1}, "size": 9, "symbol": 1}, "mode": "markers", "name": "Upper middle income1", "text": ["Belarus", "Belize", "Brazil", "China", "Colombia", "Costa Rica", "Dominican Republic", "Ecuador", "Fiji", "Guyana", "Jamaica", "Kazakhstan", "Mauritius", "Mexico", "Paraguay", "Peru", "Saint Lucia", "Samoa", "Suriname", "Thailand", "Venezuela (Bolivarian Republic of)"], "type": "scatter", "uid": "0fa3772a-e8f6-4c4f-9ef0-0def6ece5be9", "x": [2.4535958860306226, 0.3369386828657501, 1.997276447247675, 0.9558122042262029, 0.5584169181159023, 1.5066192246778587, 0.5301307691583019, 0.5093591509798445, 0.20662157658623212, 0.4978375866751736, 1.0337605874234541, 2.5095443715772423, 0.8297214031642328, 1.0354694944667955, 1.5239991525913947, 0.08765875825180407, 1.7432207089074665, 1.3033232743931387, 0.1803603317835855, 0.03895176613027565, 0.9692790523744799], "y": [0.7104925529617082, 0.44581760101456813, 0.9848925381863434, 0.17197790996604181, 0.8942725271913622, 0.684985934037099, 0.9245851456736642, 0.5887821065306609, 1.2928499250836165, 0.6285223572835672, 0.828814545023756, 0.07444356080576818, 0.09742346051151159, -0.1313112938931649, 0.3042722 ...
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead

# %% [markdown]
# ### Analysis 4: Different Cluster Numbers & One Spectral Clustering

# %% [markdown]
# #### Additional Analysis 1 with Health data. K means using 3 clusters

# %%
cluster_labels_1_health, centers_1_health = perform_kmeans(X_health, 3)
protein_group_merged_stunting_ow_master_df["additional_cluster_1"] = cluster_labels_1_health

# %%
plot_plotly(protein_group_merged_stunting_ow_master_df,"Income group",centers_1_health,3,"Health + Foods","additional_cluster_1")
# Out:
# <div>
#
#
#             <div id="ac7c1019-b746-4868-a62f-1a34e239e37c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ac7c1019-b746-4868-a62f-1a34e239e37c")) {
#                     Plotly.newPlot(
#                         'ac7c1019-b746-4868-a62f-1a34e239e37c',
#                         [{"marker": {"color": "rgb(150,0,90)", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "Low income0", "text": [], "type": "scatter", "uid": "ad592f77-9052-40ee-b018-7101885921cd", "x": [], "y": []}, {"marker": {"color": "rgb(0,0,200)", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "Low income1", "text": ["Afghanistan", "Benin", "Burkina Faso", "Central African Republic", "Chad", "Democratic People's Republic of Korea", "Ethiopia", "Gambia", "Guinea", "Guinea-Bissau", "Haiti", "Liberia", "Madagascar", "Malawi", "Mali", "Mozambique", "Nepal", "Niger", "Rwanda", "Senegal", "Sierra Leone", "Tajikistan", "Togo", "Uganda", "United Republic of Tanzania", "Yemen", "Zimbabwe"], "type": "scatter", "uid": "c0bd305e-7de8-4420-85ba-fcf3212934a2", "x": [-1.6286069371877256, -1.7848432283345994, -1.3166930936805747, -1.96705909282886, -2.1348783194523433, -1.5020617474213798, -2.0617191115952176, -1.4061575004676177, -1.7895834669526627, -1.654756205859354, -1.3553790874746248, -1.9177594277223178, -2.6163153045535337, -2.0479948394395304, -1.0281782284498067, -2.0619244706084254, -1.900972514990409, -2.01778646535297, -2.0291329542782433, -1.2989766014545379, -1.7520890169512728, -0.9230762246405538, -1.85553237476423, -1.6132691026718238, -1.835691715652664, -2.098506755251877, -1.211000637918831], "y": [-1.6082628900777034, 0.442166648269436, -1.236319112996141, 1.2216587487793753, -0.7896862061626476, 0.13034979787091103, -1.0721818443460107, -0.6479039465045129, -0.18014179985779796, -0.0003973569031787404, 0.6522939111375664, 0.3176457588227862, -0.2618064234147578, -0.7239954106447661, -1.4006402923512524, -0.057439289095218636, -1.0834143900466484, -0.7138712348691119, 0.9463730788256052, 0.12013806816496553, 0.5023850994393395, -0.48544826461939583, -0.006795871593403353, 1.0773896032362371, 0.21848013849947936, -1.1489137431904306, -0.5366546897733981]}, {"marker": {"color": "rgb(10,152,255)", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "Low income2", "text": [], "type": "scatter", "uid": "99cbdf22-4d45-408c-8fce-516a2a5a6aea", "x": [], "y": []}, {"marker": {"color": "rgb(150,0,90)", "line": {"width": 1}, "size": 9, "symbol": 1}, "mode": "markers", "name": "Upper middle income0", "text": ["Belarus", "Belize", "Brazil", "China", "Colombia", "Costa Rica", "Dominican Republic", "Ecuador", "Fiji", "Gabon", "Guyana", "Jamaica", "Kazakhstan", "Malaysia", "Maldives", "Mauritius", "Mexico", "Paraguay", "Peru", "Saint Lucia", "Samoa", "Suriname", "Thailand", "Venezuela (Bolivarian Republic of)"], "type": "scatter", "uid": "4be3e2a5-17d4-44a7-9c77-14addc57fb4a", "x": [2.4535958860306226, 0.3369386828657501, 1.997276447247675, 0.9558122042262029, 0.5584169181159023, 1.5066192246778587, 0.5301307691583019, 0.5093591509798445, 0.20662157658623212, -0.009990347743437093, 0.4978375866751736, 1.0337605874234541, 2.5095443715772423, -0.02737805995105249, -0.17820783787282754, 0.8297214031642328, 1.0354694944667955, 1.5239991525913947, 0.08765875825180407, 1.7432207089074665, 1.3033232743931387, 0.1803603317835855, 0.03895176613027565, 0.9692790523744799], "y": [0.7104925529617082, 0.44581760101456813, 0.9848925381863434, 0.17197790996604181, 0.8942725271913622, 0.684985934037099, 0.9245851456736642, 0.5887821065306609, 1.2928499250836165, 1.09251639029393, 0.6285223572835672, 0.828814545023756, 0.07444356080576818, 1.631742068788187, 5.495113156296888, 0.09742346051151159, -0.1313112938931649, 0.30427220218879497, 0.2793735451208047, 1.5409622550110842, 2.8128641393734997, 0.8808357658576551, 0.7528836726560928, 0.5140951052867424]}, {"marker": {"color": "rgb(0,0,200)", "line": {"width": 1}, "size": 9, "symbol": 1}, "mode": "markers", "name": "Upper middle income1", "text": ["Botswana", "Guatemala", "Namibia"], "type": "scatter", "uid": "cd505158-6430-4729-91c5-7e25fd205ef2", "x": [-0.3999296704753587, -1.5868548415055708, -0.8326602246614644 ...
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead

# %% [markdown]
# ####  Additional Analysis 2 with Health data. Spectral Clustering using 3 clusters

# %%
from sklearn.cluster import SpectralClustering

def spect_kmeans(X,cluste_num):
    clustering = SpectralClustering(cluste_num,assign_labels="discretize",random_state=0).fit(X)
    return clustering.labels_, "no center"

# %%
cluster_labels_2_health, centers_2_health = spect_kmeans(X_health, 3)
protein_group_merged_stunting_ow_master_df["additional_spect_cluster_2"] = cluster_labels_2_health
plot_plotly(protein_group_merged_stunting_ow_master_df,"Income group",centers_2_health,3,"Health + Foods","additional_spect_cluster_2")
# Out:
# <div>
#
#
#             <div id="e3d1ae4b-745a-4054-b30e-57833c56471c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("e3d1ae4b-745a-4054-b30e-57833c56471c")) {
#                     Plotly.newPlot(
#                         'e3d1ae4b-745a-4054-b30e-57833c56471c',
#                         [{"marker": {"color": "rgb(150,0,90)", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "Low
0.17197790996604181, 0.8942725271913622, 0.684985934037099, 0.9245851456736642, 0.5887821065306609, 1.2928499250836165, 1.09251639029393, 0.6285223572835672, 0.828814545023756, -0.6330112768141083, 0.07444356080576818, -0.5511957943859567, 1.631742068788187, 5.495113156296888, 0.09742346051151159, -0.1313112938931649, 0.30427220218879497, 0.2793735451208047, 1.5409622550110842, 2.8128641393734997, -0.47447676064518013, 0.8808357658576551, 0.7528836726560928, -0.36889652340253876, 0.5140951052867424]}, {"marker": {"color": "rgb(0,0,200)", "line": {"width": 1}, "size": 9, "symbol": 1}, "m ...
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead

# %% [markdown]
# #### Additional Analysis 3 with Socio data. K means Clustering using 3 clusters

# %%
cluster_labels_3, centers_3 = perform_kmeans(X_socio, 3)
socio_pca_dropped_df["additional_cluster_3"] = cluster_labels_3
plot_plotly(socio_pca_dropped_df,"Income group",centers_3,3,"Socioeconomic + Foods" ,"additional_cluster_3")
# Out:
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:44: FutureWarning:
#
# elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <div>
#
#
#             <div id="64cf8cb5-4149-4275-9787-c3f4d9976af3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("64cf8cb5-4149-4275-9787-c3f4d9976af3")) {
#                     Plotly.newPlot(
#                         '64cf8cb5-4149-4275-9787-c3f4d9976af3',
#                         [{"marker": {"color": "rgb(150,0,90)", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "Low income0", "text": ["Afghanistan", "Benin", "Burkina Faso", "Chad", "Ethiopia", "Gambia", "Guinea", "Guinea-Bissau", "Liberia", "Madagascar", "Malawi", "Mali", "Mozambique", "Nepal", "Niger", "Senegal", "Tajikistan", "Togo", "United Republic of Tanzania", "Yemen", "Zimbabwe"], "type": "scatter", "uid": "5c5adbcc-52a4-44db-b536-a224f043e31a", "x": [-1.697410120640752, -1.5411073255710999, -1.8539552547660936, -1.8090522015872292, -1.9195208735208957, -1.650128614626429, -1.7842496101926266, -1.8150146530856845, -1.7000333639582839, -1.6878487456536, -1.9666126669108592, -1.2968517618007933, -1.7723817440690093, -1.7785324979852302, -1.590223922718095, -1.5851167698078001, -1.6050790260876788, -1.8765681374298009, -1.6353417883446704, -1.6011940361906098, -1.6098223216152385], "y": [-1.5434506618250943, 0.2693360518944025, -1.5374577585581481, -0.9700448324106417, -1.1130018126159025, -0.8310875138021281, -0.18044270196046794, 0.17229614576998234, 0.04394355073132196, -0.4557942236872599, -0.7106244155014685, -1.6877989536602744, -0.03610867540110736, -1.2115414050601474, -1.030342217517311, -0.4405568184577929, -0.8856664360915395, -0.09294091535223646, 0.06344841595426143, -1.2357889925354657, -0.7891891349791984]}, {"marker": {"color": "rgb(0,0,200)", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "Low income1", "text": [], "type": "scatter", "uid": "1adabbbb-018e-4654-b458-00d8d5cf6097", "x": [], "y": []}, {"marker": {"color": "rgb(10,152,255)", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "Low income2", "text": ["Central African Republic", "Haiti", "Rwanda", "Sierra Leone", "Uganda"], "type": "scatter", "uid": "c0adac97-a544-4ef8-8428-651fb9cb9d1d", "x": [-1.1713140385964975, -1.7527538191992473, -1.8783042629902822, -1.6431078242186399, -1.681880805191861], "y": [0.5252124380814305, 1.0337133515907215, 1.5130943997920991, 0.7477848395791405, 1.4444051743624156]}, {"marker": {"color": "rgb(150,0,90)", "line": {"width": 1}, "size": 9, "symbol": 1}, "mode": "markers", "name": "Upper middle income0", "text": ["Algeria", "Armenia", "Azerbaijan", "Belize", "Bosnia and Herzegovina", "Botswana", "Bulgaria", "China, mainland", "Colombia", "Cuba", "Guatemala", "Guyana", "Iran (Islamic Republic of)", "Iraq", "Jordan", "Mauritius", "Mexico", "Namibia", "Paraguay", "Peru", "Romania", "Serbia", "South Africa", "Suriname", "Turkey", "Turkmenistan"], "type": "scatter", "uid": "21dfa9c2-5c17-42a2-b09e-91a0f09ff7e4", "x": [-0.8440685189793667, 0.09278812044825452, -0.7716116820685527, -0.5541004063659856, -0.5742328253056509, -0.8796449326264388, 0.10002931429037883, -0.3854075250513515, 0.0695335281553716, -0.48385716893534764, -1.3748089984784013, -0.38305852681855296, -0.9224043218741698, -1.405305273829591, -0.582768375439522, -0.10484702475569553, 0.22307854931906426, -0.9454226261450629, -0.14254990832575198, -0.6305546458196787, 0.4538360103147787, -0.13757455395517001, -0.3316694602179114, -0.3492598641909243, -0.1996661610381046, -0.1789231253295809], "y": [-2.055723415318895, -0.9382790136973391, -2.0334849113621662, -0.05600547589131159, -1.154788450463492, -0.6273614852013268, -0.8579177739878006, -0.17923554335824005, 0.11997553718127095, -0.3337701762790485, 0.03483450198722658, -0.06744429792786755, -1.300773373483378, -1.4571321999413949, -1.2242653003132364, -0.32211634944072765, -0.7705711443991067, -0.07411443398426855, -0.2491721913176558, -0.07270629277330096, -1.4537239305437173, -0.5980761513751194, -1.2818053858163327, -0.03713218984481795, -1.6227730410045826, -1.8493517879497932]}, {"marker": {"color": "rgb(0,0,200)", "line": {"width": 1}, "size": 9, "symbol": 1}, "mode": "markers", "name": "Upper middle income1", "text": ["Albania", "Belarus", "Brazil", "Kazakhstan", "Montenegro", "Russian Federation", "Venezuela (Boliva ...
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead

# %% [markdown]
# #### Additional Analysis 4 with Protein Foods data. K means Clustering using 3 clusters

# %%
cluster_labels_4, centers_4 = perform_kmeans(X, 3)
protein_group_merged_df["additional_cluster_4"] = cluster_labels_4
plot_plotly(protein_group_merged_df,"Income group",centers_4,3,"Foods","additional_cluster_4")
# Out:
# C:\Users\XuP-intern\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:44: FutureWarning:
#
# elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <div>
#
#
#             <div id="b7183ddb-9ada-4de6-8904-ce22b11ee1f7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("b7183ddb-9ada-4de6-8904-ce22b11ee1f7")) {
#                     Plotly.newPlot(
#                         'b7183ddb-9ada-4de6-8904-ce22b11ee1f7',
#                         [{"marker": {"color": "rgb(150,0,90)", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "Low income0", "text": [], "type": "scatter", "uid": "3606127e-b330-4ca4-ace5-8f0ade1a91c3", "x": [], "y": []}, {"marker": {"color": "rgb(0,0,200)", "line": {"width": 1}, "size": 9, "symbol": 0}, "mode": "markers", "name": "Low income1", "text": ["Afghanistan", "Benin", "Burkina Faso", "Central African Republic", "Chad", "Democratic People's Republic of Korea", "Ethiopia", "Gambia", "Guinea", "Haiti", "Madagascar", "Malawi", "Mali", "Mozambique", "Nepal", "Niger", "Rwanda", "Senegal", "Tajikistan", "Togo", "Uganda", "United Republic of Tanzania", "Yemen", "Zimbabwe"], "type": "scatter", "uid": "eebc1e07-ec8f-4198-bfa8-534395aab210", "x": [-0.5187362283538711, -2.574306620188047, -2.6988417531704827, -1.8351398693733723