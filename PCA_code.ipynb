# %% [markdown]
# <a href="https://colab.research.google.com/github/emoceanographer/WWF/blob/master/PCA_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# Defines the path to load the relevant files
path = "gdrive/My Drive/GTL_PCA/"

# %% [markdown]
# Production

# %%
path_prod = path + "fao_production_2011_13.csv"
path_land = path + "pasture_crops.csv"

# %%
production_df = pd.read_csv(path_prod,index_col='Country')
land_df = pd.read_csv(path_land,index_col = 'ISO3')

# %%
land_df
# Out:
#                           crop_area_per_ISO3_hectare  ...  Unnamed: 10
# ISO3                                                  ...
# Afghanistan                             8.066484e+06  ...          NaN
# Albania                                 6.423613e+05  ...          NaN
# Algeria                                 5.582107e+06  ...          NaN
# Angola                                  3.357759e+06  ...          NaN
# NaN                                              NaN  ...          NaN
# Argentina                               3.280245e+07  ...          NaN
# Armenia                                 5.866188e+05  ...          NaN
# Australia                               2.899305e+07  ...          NaN
# Austria                                 1.496332e+06  ...          NaN
# Azerbaijan                              1.982493e+06  ...          NaN
# NaN                                              NaN  ...          NaN
# ...

# %%
# from Frank's code; averages the values
production_df["Value"].astype(int,inplace= True)
production_df["Year"].astype(int,inplace= True)
production_mean_df = production_df.pivot_table(index=['Country','Item'], 
                                      values=['Value'],
                                      aggfunc='mean', 
                                      fill_value=0) 

production_mean_df = production_mean_df.reset_index()

# Missing Values are filled with 0 
production_pivoted_df = production_mean_df.pivot_table(index='Country', columns = 'Item', values = 'Value', 
                                      fill_value=0) 

production_pivoted_df.head(5)
# Out:
# Item                 Barley and products  ...  Wheat and products
# Country                                   ...
# Afghanistan                   441.333333  ...         4535.666667
# Albania                         7.666667  ...          295.666667
# Algeria                      1398.333333  ...         3095.333333
# Angola                          0.000000  ...            4.000000
# Antigua and Barbuda             0.000000  ...            0.000000
#
# [5 rows x 15 columns]

# %%
production_pivoted_df['Country'] land_df['Crop as Prop total']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Country'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-fda018903370> in <module>()
# ----> 1 production_pivoted_df['Country']
#
# ...
